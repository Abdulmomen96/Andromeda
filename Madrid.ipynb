# %%
import pandas as pd
import numpy as np

# %%
data_Madrid = pd.read_csv('Storms_20221115.csv', sep=';')

# %%
data_Madrid.head()
# Out:
#    Volume  MaximumRainfallIntensity  Runoff  RunoffVolume  \
# 0     4.1                       1.4       0           0.0
# 1     1.6                       0.7       0           0.0
# 2     0.1                       0.1       0           0.0
# 3     3.6                       1.2       0           0.0
# 4     0.1                       0.1       0           0.0
#
#    MaximumRunoffIntensity  HR-1  HR-2  HR-3  HR-4  HR-5  ...  PB-1   PB-2  \
# 0                     0.0    79  75.0  81.0  90.0    89  ...   944  945.0
# 1                     0.0    96  96.0  95.0  96.0    95  ...   939  940.0
# 2                     0.0    75  68.0  63.0  54.0    53  ...   943  943.0
# 3                     0.0    81  62.0  46.0  40.0    40  ...   939  939.0
# 4                     0.0    99  99.0  99.0  98.0    97  ...   935  935.0
#
#     PB-3   PB-4  PB-5  VV-1  VV-2  VV-3  VV-4  VV-5
# 0  946.0  947.0   947  1.62  0.77  0.80  0.89  0.88
# 1  941.0  941.0   941  0.72  0.77  0.67  0.73  1.04
# 2  943.0  944.0   945  2.05  1.91  2.14  2.15  2.01
# 3  939.0  939.0   940  1.94  1.90  2.17  2.19  2.20
# 4  936.0  936.0   937  2.24  2.03  1.94  1.82  1.97
#
# [5 rows x 25 columns]

# %%
x = np.load("X_train.npy")
x[:, 0]
# Out:
# array([44., 84., 93., ..., 71., 33., 20.])

# %%
data_Madrid.describe()
# Out:
#             Volume  MaximumRainfallIntensity       Runoff  RunoffVolume  \
# count  3191.000000               3191.000000  3191.000000   3191.000000
# mean      2.306769                  1.133751     0.094955      0.490034
# std       5.040442                  2.266253     0.293198      2.643682
# min       0.100000                  0.100000     0.000000      0.000000
# 25%       0.100000                  0.100000     0.000000      0.000000
# 50%       0.400000                  0.300000     0.000000      0.000000
# 75%       2.050000                  1.200000     0.000000      0.000000
# max      72.500000                 27.400000     1.000000     59.300000
#
#        MaximumRunoffIntensity         HR-1         HR-2         HR-3  \
# count             3191.000000  3191.000000  3191.000000  3191.000000
# mean                 0.440734    54.721404    54.764807    54.798339
# std                  2.230048    23.481997    23.371293    23.294947
# min                  0.000000     1.000000     1.000000     1.000000
# 25%                  0.000000    36.000000    36.000000    37.000000
# 50%                  0.000000    54.000000    53.000000    53.000000
# 75%                  0.000000    73.000000    73.000000    73.000000
# max                 28.232223   100.000000   100.000000   100.000000
#
#               HR-4         HR-5  ...         PB-1         PB-2         PB-3  \
# count  3191.000000  3191.000000  ...  3191.000000  3191.000000  3191.000000
# mean     54.842369    55.090254  ...   944.858665   944.858038   944.869320
# std      23.303721    23.384814  ...    12.217764    12.722258    12.253756
# min       2.000000     1.000000  ...   667.000000   667.000000   667.000000
# 25%      36.000000    36.000000  ...   941.000000   941.000000   941.000000
# 50%      54.000000    54.000000  ...   945.000000   945.000000   945.000000
# 75%      73.000000    74.000000  ...   950.000000   950.000000   950.000000
# max     100.000000   100.000000  ...   969.000000   962.000000   962.000000
#
#               PB-4         PB-5         VV-1         VV-2         VV-3  \
# count  3191.000000  3191.000000  3191.000000  3191.000000  3191.000000
# mean    944.876841   944.857725     1.322862     1.317932     1.327976
# std      11.841152    11.836231     1.007064     1.011543     1.019307
# min     800.000000   800.000000     0.000000     0.000000     0.000000
# 25%     941.000000   941.000000     0.590000     0.580000     0.600000
# 50%     945.000000   945.000000     1.110000     1.120000     1.120000
# 75%     950.000000   950.000000     1.830000     1.820000     1.820000
# max     961.000000   961.000000     7.230000     8.030000     7.670000
#
#               VV-4         VV-5
# count  3191.000000  3191.000000
# mean      1.327165     1.324036
# std       1.013086     1.010678
# min       0.000000     0.000000
# 25%       0.600000     0.600000
# 50%       1.100000     1.100000
# 75%       1.830000     1.830000
# max       8.750000     8.100000
#
# [8 rows x 25 columns]

# %%
X  = data_Madrid[data_Madrid.columns.difference(['Runoff', 'RunoffVolume', 'MaximumRunoffIntensity', 'Volume', 'MaximumRainfallIntensity'])]
y = data_Madrid['Runoff']
y_2 = data_Madrid['RunoffVolume']
y_3 = data_Madrid['MaximumRunoffIntensity']
y_4 = data_Madrid['Volume']
y_5 = data_Madrid['MaximumRainfallIntensity']

# %%
print(X.columns)
# Out:
# Index(['HR-1', 'HR-2', 'HR-3', 'HR-4', 'HR-5', 'PB-1', 'PB-2', 'PB-3', 'PB-4',
#        'PB-5', 'T-1', 'T-2', 'T-3', 'T-4', 'T-5', 'VV-1', 'VV-2', 'VV-3',
#        'VV-4', 'VV-5'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.plot(X['PB-1'].to_list() )

# %%
import matplotlib.pyplot as plt

plt.scatter(X['VV-1'], y_4)

# %%
X = X.to_numpy()
y = y.to_numpy()
y_2 = y_2.to_numpy()
y_3 = y_3.to_numpy()

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
sss.get_n_splits(X, y)

for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    y_2_train, y_2_test = y_2[train_index], y_2[test_index]
    y_3_train, y_3_test = y_3[train_index], y_3[test_index]
    y_4_train, y_4_test = y_4[train_index], y_4[test_index]
    y_5_train, y_5_test = y_5[train_index], y_5[test_index]
# Out:
# TRAIN: [ 996 2851 1681 ... 2363 2589  720] TEST: [ 911  582  915 1499  468 1482 2235 1886 2745 2111  315 1745  857  756
#   961 2471  772 1260 1713 1900 2921 2495  603 1712 2534  865 2924   27
#  2997 3154 3165 1288 1957 1363  432  347  732 1587 1289 2426  342 3152
#  2231 2634 1565 1002    7  680 2902 1397 1903 2259 2756  316 2822 1072
#  2356 2403 1318 2408 1025 1395 1152 2982 1391 3170  637 2055 1407  403
#   185  946 2264  636 3079 2635 1178 1898 1316 2751 1966  434 3043 1501
#  1074 2616 2453 1453  459  118 2182 3018  839 1697 1164  969 1420 2100
#  1357  693  293 1446 1673 1245 1693 1636 2026 1790  815 1628  209 3052
#  1692 1623  797 1561 1671 1831 1547  877 1552  642 2575 1320  465  696
#  1742  664 2850  526 1919 2677 1496 2216 2335 1456 2101  146  731 1582
#   864  202 2154  512 1879 2371 2397 1739 2863  799 2861 2859 1805 1180
#   694 2764 1532 2394 1445 2274 2174  384 1019 1100 1726 2915  498  880
#  2095  975  328 1968 2784 2212 2540  939 2139 2293 3017   70 1640  174
#   592  341 1916 2122  891 1536 2777 1767 1615 2109 1725 1912 2692  283
#  2949  762 1063 1724 2922 2209  794 2151  447 2074  851 2127 2106 2323
#  1096 1753  157 1816  376 2287 1267  713 1488  712  802  716 1238 2504
#  2233 1054 2573 2663 3125  111 2606  927 1291  849 1503 1729  742 1840
#  2964  913  517 1865 2121   74 2496 1248 2492 1996 2948  194  624 2159
#  1050  570 2015 1967  320 1568 2706  189 2117 1044   56 2253 2137 1005
#  2238  109 2020   25 3124 1504 2396  918 1721 1983 2444 2342 2078 1578
#  1480 2041  692 1626  841  482 2509  976 1703  131 2920 1384  378 2412
#  1053 1310 1020  112 1140 2838 2858 1720 1344 1394  405  671 3184 2720
#  2485 2379 1687  205 1655 1902 1091 1269 1315 2794  488 1336 1185 1714
#   302  528 2629 1779 1824 2462 3172  103 2072 2636 1386  336  873 1744
#    94 1159 1765 2170 1858 3092 2807 1932  535  965 1218 2876 2579 2384
#   658  248 2805 2620 2817 1935 1520 2748 1340 1361  729 1314 2130 1463
#  2423 2527 3060  392  389 2299 2251 2307  446  382  863 2957 1078 1550
#  3058  768 1484 1298 1131 3006  562 2413 1594 1624  192  801  483 2411
#  2362 3178 2229 1465  487 2064  908 1099 2681 1452  581   91 2138 1266
#   424 1135 1285 2167 2338 2749 2156 3045 2375 2061 1346 1305 1223  514
#  1877  947 2632 2933 3022  958 2532 2255 3034  231  419  683 2821  949
#  1811 2574 1544 1295  398 1757 1076 1598  809  989 3031 2733 3049  932
#   717 2036 2248  151  308 1454 2578 1393 2399 1348 2961  502 1929  986
#  2325 1134  117 1045 2481 2092  885  956 1621 1728 1635 1991 1051 2030
#   675 1277 1864 3042 1866 1702 2402  294  233    3    0 2309 2560 1150
#  1204 1067 1299 2175 2873 1788 3020 3085  935 3086 2218 2452 2198 2388
#  2595  990  695  745 2517  982  373 2648 2586  617 1846  313  859 2515
#  1588 2664  577 2341  229 1925 2699  942  783 1646 2302  897  380 2662
#  1246  427 1776 2298 1718 2650 1437 2054 1600  568 1845 1171 1343  594
#   190 2084  494 1497 2770 2671 2816 1350  684 1884  775  239  168  536
#  2880 2215 3089 2179  273 2869 2886 2919 1115 1349 2654 2039   21  241
#   820 2065 3141 1591  866 3156 1625 2267  884 2854 1241 2104 2908  920
#    26 2135 2830   48 2628  327 1541 2177 2360  379  495  176   24 2633
#  2171 1046 2911 2014 1812 1596  630 1913  848 2369 2191 2447  325 2818
#  1351   40 2889  359 2234 1011   93 3062  255 1426 2871 1986 1097 1280
#   845 1270 2377 1149 2952 2674 1749  493 1897]

# %%
sum(y_train) / y_train.shape
# Out:
# array([0.09482759])

# %%
sum(y_test) / y_test.shape
# Out:
# array([0.09546166])

# %%
import numpy as np

# %%
np.save('X_train.npy', X_train)
np.save('X_test.npy', X_test)
np.save('y_train.npy', y_train)
np.save('y_test.npy', y_test)
np.save('y_2_train.npy', y_2_train)
np.save('y_2_test.npy', y_2_test)
np.save('y_3_train.npy', y_3_train)
np.save('y_3_test.npy', y_3_test)
np.save('y_4_train.npy', y_4_train)
np.save('y_4_test.npy', y_4_test)
np.save('y_5_train.npy', y_5_train)
np.save('y_5_test.npy', y_5_test)

# %%
print(X_test.shape)
# Out:
# (639, 20)
